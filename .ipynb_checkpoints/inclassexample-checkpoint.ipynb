# %%
import pandas as pd
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
pd.read_csv('nycHistPop.csv')
# Out:
#    Source:  https://en.wikipedia.org/wiki/Demographics_of_New_York_City  \
# 0   All population figures are consistent with pre...
# 1   First census after the consolidation of the fi...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                Year
# 5                                                1698
# 6                                                1771
# 7                                                1790
# 8                                                1800
# 9                                                1810
# 10                                               1820
# 11                                               1830
# 12                                               1840
# 13                                               1850
# 14                                               1860
# 15                                               1870
# ...

# %%
pop = pd.read_csv('nycHistPop.csv', skiprows = 5)

# %%
pop
# Out:
#     Year  Manhattan  Brooklyn     Queens      Bronx  Staten Island    Total
# 0   1698       4937      2017        NaN        NaN            727     7681
# 1   1771      21863      3623        NaN        NaN           2847    28423
# 2   1790      33131      4549     6159.0     1781.0           3827    49447
# 3   1800      60515      5740     6642.0     1755.0           4563    79215
# 4   1810      96373      8303     7444.0     2267.0           5347   119734
# 5   1820     123706     11187     8246.0     2782.0           6135   152056
# 6   1830     202589     20535     9049.0     3023.0           7082   242278
# 7   1840     312710     47613    14480.0     5346.0          10965   391114
# 8   1850     515547    138882    18593.0     8032.0          15061   696115
# 9   1860     813669    279122    32903.0    23593.0          25492  1174779
# 10  1870     942292    419921    45468.0    37393.0          33029  1478103
# ...

# %%
pop.head(5)
# Out:
#    Year  Manhattan  Brooklyn  Queens   Bronx  Staten Island   Total
# 0  1698       4937      2017     NaN     NaN            727    7681
# 1  1771      21863      3623     NaN     NaN           2847   28423
# 2  1790      33131      4549  6159.0  1781.0           3827   49447
# 3  1800      60515      5740  6642.0  1755.0           4563   79215
# 4  1810      96373      8303  7444.0  2267.0           5347  119734

# %%
pop.head(-2)
# Out:
#     Year  Manhattan  Brooklyn     Queens      Bronx  Staten Island    Total
# 0   1698       4937      2017        NaN        NaN            727     7681
# 1   1771      21863      3623        NaN        NaN           2847    28423
# 2   1790      33131      4549     6159.0     1781.0           3827    49447
# 3   1800      60515      5740     6642.0     1755.0           4563    79215
# 4   1810      96373      8303     7444.0     2267.0           5347   119734
# 5   1820     123706     11187     8246.0     2782.0           6135   152056
# 6   1830     202589     20535     9049.0     3023.0           7082   242278
# 7   1840     312710     47613    14480.0     5346.0          10965   391114
# 8   1850     515547    138882    18593.0     8032.0          15061   696115
# 9   1860     813669    279122    32903.0    23593.0          25492  1174779
# 10  1870     942292    419921    45468.0    37393.0          33029  1478103
# ...

# %%
pop.plot(x = 'Year')

# %%
shelter = pd.read_csv('DHS_Daily_Report.csv', parse_dates =['Date of Census'])

# %%
shelter
# Out:
#     Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0       2020-01-02                    38039                      21341
# 1       2020-01-03                    37963                      21288
# 2       2020-01-04                    37952                      21292
# 3       2020-01-05                    38174                      21367
# 4       2020-01-06                    38171                      21327
# ..             ...                      ...                        ...
# 173     2020-06-25                    36605                      19018
# 174     2020-06-26                    36530                      18983
# 175     2020-06-28                    36556                      18984
# 176     2020-06-29                    36565                      18980
# 177     2020-06-30                    36562                      18991
#
#      Total Individuals in Shelter  Single Adult Men in Shelter  \
# ...

# %%
shelter.dtypes
# Out:
# Date of Census                                             datetime64[ns]
# Total Adults in Shelter                                             int64
# Total Children in Shelter                                           int64
# Total Individuals in Shelter                                        int64
# Single Adult Men in Shelter                                         int64
# Single Adult Women in Shelter                                       int64
# Total Single Adults in Shelter                                      int64
# Families with Children in Shelter                                   int64
# Adults in Families with Children in Shelter                         int64
# Children in Families with Children in Shelter                       int64
# Total Individuals in Families with Children in Shelter              int64
# Adult Families in Shelter                                           int64
# Individuals in Adult Families in Shelter                            int64
# ...

# %%
shelter.plot(x = 'Date of Census', y = 'Total Individuals in Shelter')

# %%
shelter2 = pd.read_csv('DHS_Daily_Report (1).csv', parse_dates =['Date of Census'])

# %%
shelter2.plot(x = 'Date of Census', y = 'Total Individuals in Shelter')

# %%
shelter.plot(x = 'Date of Census', y = 'Total Individuals in Shelter')
shelter2.plot(x = 'Date of Census', y = 'Total Individuals in Shelter')

# %%
shelter2.plot(x = 'Date of Census').legend(bbox_to_anchor = (1,1))

# %%
shelter['Total Adults in Shelter'].head()
# Out:
# 0    38039
# 1    37963
# 2    37952
# 3    38174
# 4    38171
# Name: Total Adults in Shelter, dtype: int64

# %%
shelter['Total Adults in Shelter']/shelter['Total Individuals in Shelter']
# Out:
# 0      0.640603
# 1      0.640715
# 2      0.640605
# 3      0.641138
# 4      0.641551
#          ...
# 173    0.658091
# 174    0.658044
# 175    0.658192
# 176    0.658295
# 177    0.658146
# Length: 178, dtype: float64

# %%
shelter['Proportion Adults'] = shelter['Total Adults in Shelter']/shelter['Total Individuals in Shelter']

# %%
shelter
# Out:
#     Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0       2020-01-02                    38039                      21341
# 1       2020-01-03                    37963                      21288
# 2       2020-01-04                    37952                      21292
# 3       2020-01-05                    38174                      21367
# 4       2020-01-06                    38171                      21327
# ..             ...                      ...                        ...
# 173     2020-06-25                    36605                      19018
# 174     2020-06-26                    36530                      18983
# 175     2020-06-28                    36556                      18984
# 176     2020-06-29                    36565                      18980
# 177     2020-06-30                    36562                      18991
#
#      Total Individuals in Shelter  Single Adult Men in Shelter  \
# ...

# %%
shelter.plot(x = 'Date of Census', y = 'Proportion Adults')
