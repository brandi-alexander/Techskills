# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
bigfoot = pd.read_csv('bfro-report-locations.csv')

# %%
bigfoot.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
bigfoot.dtypes
# Out:
# number              int64
# title              object
# classification     object
# timestamp          object
# latitude          float64
# longitude         float64
# dtype: object

# %%
bigfoot['time'] = pd.to_datetime(bigfoot['timestamp'])

# %%
bigfoot.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude                      time
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000 2000-06-16 12:00:00+00:00
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982 1995-05-15 12:00:00+00:00
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202 2004-02-09 12:00:00+00:00
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667 2004-06-18 12:00:00+00:00
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853 2004-02-15 12:00:00+00:00

# %%
bigfoot.dtypes
# Out:
# number                          int64
# title                          object
# classification                 object
# timestamp                      object
# latitude                      float64
# longitude                     float64
# time              datetime64[ns, UTC]
# dtype: object

# %%
sns.distplot(bigfoot['time'])

# %%
import folium

# %%
m = folium.Map(location = [61.5000, -142.9000], zoom_start = 3)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, row in bigfoot.head(100).iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup = row['title']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bigfoot.groupby(by =[bigfoot['time'].dt.month]).count()
# Out:
#       number  title  classification  timestamp  latitude  longitude  time
# time
# 1        247    247             247        247       247        247   247
# 2        160    160             160        160       160        160   160
# 3        172    172             172        172       172        172   172
# 4        214    214             214        214       214        214   214
# 5        258    258             258        258       258        258   258
# 6        344    344             344        344       344        344   344
# 7        481    481             481        481       481        481   481
# 8        458    458             458        458       458        458   458
# 9        402    402             402        402       402        402   402
# 10       497    497             497        497       497        497   497
# 11       367    367             367        367       367        367   367
# 12       210    210             210        210       210        210   210
