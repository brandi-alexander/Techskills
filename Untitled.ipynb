# %%
import pandas as pd
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
movies = pd.read_csv('IMDB.csv')
movies.head()
# Out:
#    X                    Title  Rating  TotalVotes     Genre1     Genre2  \
# 0  1  12 Years a Slave (2013)     8.1      496092  Biography      Drama
# 1  2         127 Hours (2010)     7.6      297075  Adventure  Biography
# 2  3             50/50 (2011)     7.7      283935     Comedy      Drama
# 3  4        About Time (2013)     7.8      225412     Comedy      Drama
# 4  5             Amour (2012)     7.9       76121      Drama    Romance
#
#     Genre3  MetaCritic      Budget  Runtime  ...  Votes45A  Votes45AM  \
# 0  History        96.0  20000000.0  134 min  ...       7.8        7.8
# 1    Drama        82.0  18000000.0   94 min  ...       7.3        7.3
# 2  Romance        72.0   8000000.0  100 min  ...       7.4        7.4
# 3  Fantasy         NaN  12000000.0  123 min  ...       7.6        7.5
# 4      NaN        94.0   8900000.0  127 min  ...       7.9        7.8
#
#    Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS      Domestic  \
# 0        8.1        8.0        7.7      8.3       8.0  $56,671,993
# 1        7.5        7.6        7.0      7.7       7.6  $18,335,230
# 2        7.5        7.4        7.0      7.9       7.6  $35,014,192
# 3        7.8        7.7        6.9      7.8       7.7  $15,322,921
# 4        8.1        6.6        7.2      7.9       7.8   $6,739,492
#
#      Foreign      Worldwide
# 0  131061209  $187,733,202
# 1   42403567   $60,738,797
# 2    4173591   $39,187,783
# 3   71777528   $87,100,449
# 4   13100000   $19,839,492
#
# [5 rows x 58 columns]

# %%
print(movies.shape)
# Out:
# (117, 58)

# %%
print(movies.shape[0])
# Out:
# 117

# %%
print(movies.shape[1])
# Out:
# 58

# %%
movies.columns
# Out:
# Index(['X', 'Title', 'Rating', 'TotalVotes', 'Genre1', 'Genre2', 'Genre3',
#        'MetaCritic', 'Budget', 'Runtime', 'CVotes10', 'CVotes09', 'CVotes08',
#        'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04', 'CVotes03', 'CVotes02',
#        'CVotes01', 'CVotesMale', 'CVotesFemale', 'CVotesU18', 'CVotesU18M',
#        'CVotesU18F', 'CVotes1829', 'CVotes1829M', 'CVotes1829F', 'CVotes3044',
#        'CVotes3044M', 'CVotes3044F', 'CVotes45A', 'CVotes45AM', 'CVotes45AF',
#        'CVotes1000', 'CVotesUS', 'CVotesnUS', 'VotesM', 'VotesF', 'VotesU18',
#        'VotesU18M', 'VotesU18F', 'Votes1829', 'Votes1829M', 'Votes1829F',
#        'Votes3044', 'Votes3044M', 'Votes3044F', 'Votes45A', 'Votes45AM',
#        'Votes45AF', 'VotesIMDB', 'Votes1000', 'VotesUS', 'VotesnUS',
#        'Domestic', 'Foreign', 'Worldwide'],
#       dtype='object')

# %%
movies = movies.drop(['X'], axis = 1)
movies.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-66efc994ee85> in <module>
# ----> 1 movies = movies.drop(['X'], axis = 1)
#       2 movies.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['X'] not found in axis"

# %%
movies.head()
# Out:
#                      Title  Rating  TotalVotes     Genre1     Genre2   Genre3  \
# 0  12 Years a Slave (2013)     8.1      496092  Biography      Drama  History
# 1         127 Hours (2010)     7.6      297075  Adventure  Biography    Drama
# 2             50/50 (2011)     7.7      283935     Comedy      Drama  Romance
# 3        About Time (2013)     7.8      225412     Comedy      Drama  Fantasy
# 4             Amour (2012)     7.9       76121      Drama    Romance      NaN
#
#    MetaCritic      Budget  Runtime  CVotes10  ...  Votes45A  Votes45AM  \
# 0        96.0  20000000.0  134 min     75556  ...       7.8        7.8
# 1        82.0  18000000.0   94 min     28939  ...       7.3        7.3
# 2        72.0   8000000.0  100 min     28304  ...       7.4        7.4
# 3         NaN  12000000.0  123 min     38556  ...       7.6        7.5
# 4        94.0   8900000.0  127 min     11093  ...       7.9        7.8
#
#    Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS      Domestic  \
# 0        8.1        8.0        7.7      8.3       8.0  $56,671,993
# 1        7.5        7.6        7.0      7.7       7.6  $18,335,230
# 2        7.5        7.4        7.0      7.9       7.6  $35,014,192
# 3        7.8        7.7        6.9      7.8       7.7  $15,322,921
# 4        8.1        6.6        7.2      7.9       7.8   $6,739,492
#
#      Foreign      Worldwide
# 0  131061209  $187,733,202
# 1   42403567   $60,738,797
# 2    4173591   $39,187,783
# 3   71777528   $87,100,449
# 4   13100000   $19,839,492
#
# [5 rows x 57 columns]

# %%
movies2 = pd.read_csv('IMDB.csv', index_col = 'Title')
movies.head()
# Out:
#                      Title  Rating  TotalVotes     Genre1     Genre2   Genre3  \
# 0  12 Years a Slave (2013)     8.1      496092  Biography      Drama  History
# 1         127 Hours (2010)     7.6      297075  Adventure  Biography    Drama
# 2             50/50 (2011)     7.7      283935     Comedy      Drama  Romance
# 3        About Time (2013)     7.8      225412     Comedy      Drama  Fantasy
# 4             Amour (2012)     7.9       76121      Drama    Romance      NaN
#
#    MetaCritic      Budget  Runtime  CVotes10  ...  Votes45A  Votes45AM  \
# 0        96.0  20000000.0  134 min     75556  ...       7.8        7.8
# 1        82.0  18000000.0   94 min     28939  ...       7.3        7.3
# 2        72.0   8000000.0  100 min     28304  ...       7.4        7.4
# 3         NaN  12000000.0  123 min     38556  ...       7.6        7.5
# 4        94.0   8900000.0  127 min     11093  ...       7.9        7.8
#
#    Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS      Domestic  \
# 0        8.1        8.0        7.7      8.3       8.0  $56,671,993
# 1        7.5        7.6        7.0      7.7       7.6  $18,335,230
# 2        7.5        7.4        7.0      7.9       7.6  $35,014,192
# 3        7.8        7.7        6.9      7.8       7.7  $15,322,921
# 4        8.1        6.6        7.2      7.9       7.8   $6,739,492
#
#      Foreign      Worldwide
# 0  131061209  $187,733,202
# 1   42403567   $60,738,797
# 2    4173591   $39,187,783
# 3   71777528   $87,100,449
# 4   13100000   $19,839,492
#
# [5 rows x 57 columns]

# %%
movies3 = pd.read_csv('IMDB.csv')
movies3.head()
# Out:
#    X                    Title  Rating  TotalVotes     Genre1     Genre2  \
# 0  1  12 Years a Slave (2013)     8.1      496092  Biography      Drama
# 1  2         127 Hours (2010)     7.6      297075  Adventure  Biography
# 2  3             50/50 (2011)     7.7      283935     Comedy      Drama
# 3  4        About Time (2013)     7.8      225412     Comedy      Drama
# 4  5             Amour (2012)     7.9       76121      Drama    Romance
#
#     Genre3  MetaCritic      Budget  Runtime  ...  Votes45A  Votes45AM  \
# 0  History        96.0  20000000.0  134 min  ...       7.8        7.8
# 1    Drama        82.0  18000000.0   94 min  ...       7.3        7.3
# 2  Romance        72.0   8000000.0  100 min  ...       7.4        7.4
# 3  Fantasy         NaN  12000000.0  123 min  ...       7.6        7.5
# 4      NaN        94.0   8900000.0  127 min  ...       7.9        7.8
#
#    Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS      Domestic  \
# 0        8.1        8.0        7.7      8.3       8.0  $56,671,993
# 1        7.5        7.6        7.0      7.7       7.6  $18,335,230
# 2        7.5        7.4        7.0      7.9       7.6  $35,014,192
# 3        7.8        7.7        6.9      7.8       7.7  $15,322,921
# 4        8.1        6.6        7.2      7.9       7.8   $6,739,492
#
#      Foreign      Worldwide
# 0  131061209  $187,733,202
# 1   42403567   $60,738,797
# 2    4173591   $39,187,783
# 3   71777528   $87,100,449
# 4   13100000   $19,839,492
#
# [5 rows x 58 columns]

# %%
movies3 = movies3.rename(columns = {'X': 'Number'})
movies3.head()
# Out:
#    Number                    Title  Rating  TotalVotes     Genre1     Genre2  \
# 0       1  12 Years a Slave (2013)     8.1      496092  Biography      Drama
# 1       2         127 Hours (2010)     7.6      297075  Adventure  Biography
# 2       3             50/50 (2011)     7.7      283935     Comedy      Drama
# 3       4        About Time (2013)     7.8      225412     Comedy      Drama
# 4       5             Amour (2012)     7.9       76121      Drama    Romance
#
#     Genre3  MetaCritic      Budget  Runtime  ...  Votes45A  Votes45AM  \
# 0  History        96.0  20000000.0  134 min  ...       7.8        7.8
# 1    Drama        82.0  18000000.0   94 min  ...       7.3        7.3
# 2  Romance        72.0   8000000.0  100 min  ...       7.4        7.4
# 3  Fantasy         NaN  12000000.0  123 min  ...       7.6        7.5
# 4      NaN        94.0   8900000.0  127 min  ...       7.9        7.8
#
#    Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS      Domestic  \
# 0        8.1        8.0        7.7      8.3       8.0  $56,671,993
# 1        7.5        7.6        7.0      7.7       7.6  $18,335,230
# 2        7.5        7.4        7.0      7.9       7.6  $35,014,192
# 3        7.8        7.7        6.9      7.8       7.7  $15,322,921
# 4        8.1        6.6        7.2      7.9       7.8   $6,739,492
#
#      Foreign      Worldwide
# 0  131061209  $187,733,202
# 1   42403567   $60,738,797
# 2    4173591   $39,187,783
# 3   71777528   $87,100,449
# 4   13100000   $19,839,492
#
# [5 rows x 58 columns]

# %%
movies4 = pd.read_csv('IMDB.csv', usecols = ['Title', 'Genre1', 'Runtime'])
movies4.head()
# Out:
#                      Title     Genre1  Runtime
# 0  12 Years a Slave (2013)  Biography  134 min
# 1         127 Hours (2010)  Adventure   94 min
# 2             50/50 (2011)     Comedy  100 min
# 3        About Time (2013)     Comedy  123 min
# 4             Amour (2012)      Drama  127 min

# %%
zillow = pd.read_csv('data-zillow.csv')
zillow.head()
# Out:
#         Date  RegionID    RegionName State                           Metro  \
# 0  5/31/2017      6181      New York    NY                        New York
# 1  5/31/2017     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  5/31/2017     17426       Chicago    IL                         Chicago
# 3  5/31/2017     13271  Philadelphia    PA                    Philadelphia
# 4  5/31/2017     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
zillow.dtypes
# Out:
# Date          object
# RegionID       int64
# RegionName    object
# State         object
# Metro         object
# County        object
# SizeRank       int64
# Zhvi           int64
# dtype: object

# %%
zillow["Date"] = pd.to_datetime(zillow["Date"])
zillow['Date'].dt.year.value_counts()
# Out:
# 2017    10830
# Name: Date, dtype: int64

# %%
region =zillow['RegionName']
region.head()
# Out:
# 0        New York
# 1     Los Angeles
# 2         Chicago
# 3    Philadelphia
# 4         Phoenix
# Name: RegionName, dtype: object

# %%
type(region)
# Out:
# pandas.core.series.Series

# %%
multi_region = zillow[['RegionName', 'County']]
multi_region.head()
# Out:
#      RegionName        County
# 0      New York        Queens
# 1   Los Angeles   Los Angeles
# 2       Chicago          Cook
# 3  Philadelphia  Philadelphia
# 4       Phoenix      Maricopa

# %%
type(multi_region)
# Out:
# pandas.core.frame.DataFrame

# %%
zillow['State'].value_counts()
# Out:
# PA    1208
# NY     717
# CA     701
# NJ     577
# FL     528
# OH     507
# IL     496
# MI     461
# IN     418
# TX     397
# TN     350
# MA     334
# MD     318
# NC     293
# WA     275
# WI     270
# GA     266
# VA     228
# MO     202
# NH     190
# CT     183
# CO     166
# OR     164
# MN     155
# AL     149
# LA     148
# SC     138
# MS     135
# KY     118
# AZ     102
# AR      82
# UT      81
# OK      70
# IA      63
# KS      52
# HI      43
# RI      41
# ID      33
# DE      26
# NM      26
# NV      26
# MT      20
# NE      20
# WV      17
# AK      12
# ND      12
# WY      10
# ME       1
# DC       1
# Name: State, dtype: int64

# %%
top10states = zillow['State'].value_counts().head(n = 10)
top10states
# Out:
# PA    1208
# NY     717
# CA     701
# NJ     577
# FL     528
# OH     507
# IL     496
# MI     461
# IN     418
# TX     397
# Name: State, dtype: int64

# %%
top10states.plot(kind = 'bar')
plt.show()

# %%
top10states.plot(kind = 'barh')
plt.show()

# %%
zillow.head()
# Out:
#         Date  RegionID    RegionName State                           Metro  \
# 0 2017-05-31      6181      New York    NY                        New York
# 1 2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2 2017-05-31     17426       Chicago    IL                         Chicago
# 3 2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4 2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
zillow.loc[10,'RegionName']
# Out:
# 'San Francisco'

# %%
zillow.loc[10,['RegionName','State','Metro','County']]
# Out:
# RegionName    San Francisco
# State                    CA
# Metro         San Francisco
# County        San Francisco
# Name: 10, dtype: object

# %%
zillow.iloc[10,2]
# Out:
# 'San Francisco'

# %%
zillow.loc[15, :]
# Out:
# Date          2017-05-31 00:00:00
# RegionID                    24043
# RegionName              Charlotte
# State                          NC
# Metro                   Charlotte
# County                Mecklenburg
# SizeRank                       15
# Zhvi                       183800
# Name: 15, dtype: object

# %%
zillow.loc[1000:1010,'RegionName']
# Out:
# 1000      Penn Hills
# 1001    Bell Gardens
# 1002      Alpharetta
# 1003       Thibodaux
# 1004    Mount Juliet
# 1005    East Lansing
# 1006         Taunton
# 1007      Charleston
# 1008         Everett
# 1009      Manchester
# 1010      Prattville
# Name: RegionName, dtype: object

# %%
zillow.loc[1000:1010,'RegionName':'County']
# Out:
#         RegionName State                           Metro       County
# 1000    Penn Hills    PA                      Pittsburgh    Allegheny
# 1001  Bell Gardens    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 1002    Alpharetta    GA                         Atlanta       Fulton
# 1003     Thibodaux    LA                           Houma    Lafourche
# 1004  Mount Juliet    TN                       Nashville       Wilson
# 1005  East Lansing    MI                         Lansing       Ingham
# 1006       Taunton    MA                      Providence      Bristol
# 1007    Charleston    WV                      Charleston      Kanawha
# 1008       Everett    MA                          Boston    Middlesex
# 1009    Manchester    NJ                        New York        Ocean
# 1010    Prattville    AL                      Montgomery      Autauga

# %%
zillow.iloc[1000:1010, 2:5]
# Out:
#         RegionName State                           Metro
# 1000    Penn Hills    PA                      Pittsburgh
# 1001  Bell Gardens    CA  Los Angeles-Long Beach-Anaheim
# 1002    Alpharetta    GA                         Atlanta
# 1003     Thibodaux    LA                           Houma
# 1004  Mount Juliet    TN                       Nashville
# 1005  East Lansing    MI                         Lansing
# 1006       Taunton    MA                      Providence
# 1007    Charleston    WV                      Charleston
# 1008       Everett    MA                          Boston
# 1009    Manchester    NJ                        New York

# %%
zillow.loc[5432:5450, ['RegionName', 'State', 'Metro']]
# Out:
#               RegionName State                           Metro
# 5432    Leacock Township    PA                       Lancaster
# 5433          Villa Park    CA  Los Angeles-Long Beach-Anaheim
# 5434             Atwater    OH                           Akron
# 5435             Peotone    IL                         Chicago
# 5436  Town of Broadalbin    NY                    Gloversville
# 5437            Montague    MI                        Muskegon
# 5438      Atlantic Beach    FL                    Jacksonville
# 5439       Pine Township    PA                      Pittsburgh
# 5440             Century    FL                       Pensacola
# 5441               Lloyd    NY                        Kingston
# 5442       South Lebanon    PA                         Lebanon
# 5443  Dickinson Township    PA                      Harrisburg
# 5444    Carroll Township    PA                      Harrisburg
# 5445    Holland Township    NJ                        New York
# 5446          Manchester    MA                          Boston
# 5447       Willow Street    PA                       Lancaster
# 5448  Waterford Township    PA                            Erie
# 5449         Shillington    PA                         Reading
# 5450            Onalaska    TX                             NaN

# %%
Dallas_filter = zillow['RegionName'] == 'Dallas'
Dallas_filter
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10825    False
# 10826    False
# 10827    False
# 10828    False
# 10829    False
# Name: RegionName, Length: 10830, dtype: bool

# %%
zillow[Dallas_filter]
# Out:
#            Date  RegionID RegionName State              Metro    County  \
# 7    2017-05-31     38128     Dallas    TX  Dallas-Fort Worth    Dallas
# 2246 2017-05-31     51636     Dallas    OR              Salem      Polk
# 7312 2017-05-31     24307     Dallas    GA            Atlanta  Paulding
# 7334 2017-05-31     44845     Dallas    PA           Scranton   Luzerne
# 8345 2017-05-31     35100     Dallas    NC          Charlotte    Gaston
#
#       SizeRank    Zhvi
# 7            7  164700
# 2246      2246  234400
# 7312      7312  132700
# 7334      7334  158400
# 8345      8345   91400

# %%
zillow[zillow['RegionName']== 'Dallas']
# Out:
#            Date  RegionID RegionName State              Metro    County  \
# 7    2017-05-31     38128     Dallas    TX  Dallas-Fort Worth    Dallas
# 2246 2017-05-31     51636     Dallas    OR              Salem      Polk
# 7312 2017-05-31     24307     Dallas    GA            Atlanta  Paulding
# 7334 2017-05-31     44845     Dallas    PA           Scranton   Luzerne
# 8345 2017-05-31     35100     Dallas    NC          Charlotte    Gaston
#
#       SizeRank    Zhvi
# 7            7  164700
# 2246      2246  234400
# 7312      7312  132700
# 7334      7334  158400
# 8345      8345   91400

# %%
zillow.sort_values('Metro')
# Out:
#             Date  RegionID    RegionName State     Metro        County  \
# 9851  2017-05-31     48458      Westport    WA  Aberdeen  Grays Harbor
# 4996  2017-05-31     36873          Elma    WA  Aberdeen  Grays Harbor
# 5090  2017-05-31     35514       Hoquiam    WA  Aberdeen  Grays Harbor
# 9401  2017-05-31     33215  Ocean Shores    WA  Aberdeen  Grays Harbor
# 9149  2017-05-31     18370      Grayland    WA  Aberdeen  Grays Harbor
# ...          ...       ...           ...   ...       ...           ...
# 10764 2017-05-31     35349        Fraser    CO       NaN         Grand
# 10768 2017-05-31     17816       Dresser    WI       NaN          Polk
# 10774 2017-05-31     34232      Tamworth    NH       NaN       Carroll
# 10822 2017-05-31     18317     Goldsboro    MD       NaN      Caroline
# 10825 2017-05-31     26077       Nehalem    OR       NaN     Tillamook
#
#        SizeRank    Zhvi
# 9851       9851  144600
# 4996       4996  175200
# 5090       5090   95700
# 9401       9401  152400
# 9149       9149  143900
# ...         ...     ...
# 10764     10764  274500
# 10768     10768  189900
# 10774     10774  164100
# 10822     10822  175700
# 10825     10825  392200
#
# [10830 rows x 8 columns]

# %%
zillow.sort_values('Metro', ascending = False)
# Out:
#             Date  RegionID   RegionName State       Metro     County  \
# 8064  2017-05-31     19538     Nashport    OH  Zanesville  Muskingum
# 10271 2017-05-31     15262     Hopewell    OH  Zanesville  Muskingum
# 10373 2017-05-31     49730      Norwich    OH  Zanesville  Muskingum
# 5423  2017-05-31     53527  New Concord    OH  Zanesville  Muskingum
# 7595  2017-05-31     17815      Dresden    OH  Zanesville  Muskingum
# ...          ...       ...          ...   ...         ...        ...
# 10764 2017-05-31     35349       Fraser    CO         NaN      Grand
# 10768 2017-05-31     17816      Dresser    WI         NaN       Polk
# 10774 2017-05-31     34232     Tamworth    NH         NaN    Carroll
# 10822 2017-05-31     18317    Goldsboro    MD         NaN   Caroline
# 10825 2017-05-31     26077      Nehalem    OR         NaN  Tillamook
#
#        SizeRank    Zhvi
# 8064       8064  153800
# 10271     10271  138700
# 10373     10373  145100
# 5423       5423  138300
# 7595       7595  118400
# ...         ...     ...
# 10764     10764  274500
# 10768     10768  189900
# 10774     10774  164100
# 10822     10822  175700
# 10825     10825  392200
#
# [10830 rows x 8 columns]

# %%
zillow.sort_values(by = ['State', 'Metro'])
# Out:
#             Date  RegionID RegionName State      Metro                County  \
# 57    2017-05-31     23482  Anchorage    AK  Anchorage             Anchorage
# 1793  2017-05-31     36906     Palmer    AK  Anchorage     Matanuska Susitna
# 4450  2017-05-31    102611    Tanaina    AK  Anchorage     Matanuska Susitna
# 5996  2017-05-31    395445      Lakes    AK  Anchorage     Matanuska Susitna
# 842   2017-05-31     38465  Fairbanks    AK  Fairbanks  Fairbanks North Star
# ...          ...       ...        ...   ...        ...                   ...
# 10171 2017-05-31     23888      Burns    WY   Cheyenne               Laramie
# 2559  2017-05-31     15743   Riverton    WY   Riverton               Fremont
# 3715  2017-05-31     25498     Lander    WY   Riverton               Fremont
# 8823  2017-05-31     38244     Dubois    WY   Riverton               Fremont
# 3948  2017-05-31      8885    Rawlins    WY        NaN                Carbon
#
#        SizeRank    Zhvi
# 57           57  293900
# 1793       1793  247800
# 4450       4450  224700
# 5996       5996  249700
# 842         842  221000
# ...         ...     ...
# 10171     10171  193500
# 2559       2559  159600
# 3715       3715  191300
# 8823       8823  225400
# 3948       3948  152100
#
# [10830 rows x 8 columns]

# %%
sorted = zillow.sort_values(by = ['Metro','County','Zhvi'],ascending = [True, False, False])
sorted.head()
# Out:
#            Date  RegionID    RegionName State     Metro        County  \
# 7108 2017-05-31      6275      Oakville    WA  Aberdeen  Grays Harbor
# 4568 2017-05-31     56078     Montesano    WA  Aberdeen  Grays Harbor
# 4996 2017-05-31     36873          Elma    WA  Aberdeen  Grays Harbor
# 8420 2017-05-31     19269      McCleary    WA  Aberdeen  Grays Harbor
# 9401 2017-05-31     33215  Ocean Shores    WA  Aberdeen  Grays Harbor
#
#       SizeRank    Zhvi
# 7108      7108  186900
# 4568      4568  182000
# 4996      4996  175200
# 8420      8420  170700
# 9401      9401  152400

# %%
price_filter = zillow['Zhvi'] >= 5000000
price_filter.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Zhvi, dtype: bool

# %%
zillow[price_filter]
# Out:
#            Date  RegionID RegionName State          Metro     County  \
# 4629 2017-05-31     30280   Atherton    CA  San Francisco  San Mateo
#
#       SizeRank     Zhvi
# 4629      4629  6343800

# %%
new_price_filter = zillow ['Zhvi'] > 2500000
state_filter = zillow['State'] == 'NY'

# %%
zillow[new_price_filter & state_filter]
# Out:
#             Date  RegionID  RegionName State     Metro   County  SizeRank  \
# 9714  2017-05-31      7774  Water Mill    NY  New York  Suffolk      9714
# 10203 2017-05-31     30203  Amagansett    NY  New York  Suffolk     10203
#
#           Zhvi
# 9714   4085200
# 10203  2613800

# %%
zillow[new_price_filter | (zillow['State'] == 'NY)'].head()
# Out:
#   File "<ipython-input-81-8d4a43f66f8a>", line 1
#     zillow[new_price_filter | (zillow['State'] == 'NY)'].head()
#                                                        ^
# SyntaxError: invalid syntax

# %%
zillow[new_price_filter | (zillow['State'] == 'NY')].head()
# Out:
#           Date  RegionID            RegionName State     Metro       County  \
# 0   2017-05-31      6181              New York    NY  New York       Queens
# 138 2017-05-31     34937               Yonkers    NY  New York  Westchester
# 173 2017-05-31      7353              Syracuse    NY  Syracuse     Onondaga
# 317 2017-05-31     37074                Albany    NY    Albany       Albany
# 406 2017-05-31    398360  Town of Poughkeepsie    NY  New York     Dutchess
#
#      SizeRank    Zhvi
# 0           0  672400
# 138       138  439700
# 173       173   82300
# 317       317  169500
# 406       406  207800

# %%
movies.head()
# Out:
#    X                    Title  Rating  TotalVotes     Genre1     Genre2  \
# 0  1  12 Years a Slave (2013)     8.1      496092  Biography      Drama
# 1  2         127 Hours (2010)     7.6      297075  Adventure  Biography
# 2  3             50/50 (2011)     7.7      283935     Comedy      Drama
# 3  4        About Time (2013)     7.8      225412     Comedy      Drama
# 4  5             Amour (2012)     7.9       76121      Drama    Romance
#
#     Genre3  MetaCritic      Budget  Runtime  ...  Votes45A  Votes45AM  \
# 0  History        96.0  20000000.0  134 min  ...       7.8        7.8
# 1    Drama        82.0  18000000.0   94 min  ...       7.3        7.3
# 2  Romance        72.0   8000000.0  100 min  ...       7.4        7.4
# 3  Fantasy         NaN  12000000.0  123 min  ...       7.6        7.5
# 4      NaN        94.0   8900000.0  127 min  ...       7.9        7.8
#
#    Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS      Domestic  \
# 0        8.1        8.0        7.7      8.3       8.0  $56,671,993
# 1        7.5        7.6        7.0      7.7       7.6  $18,335,230
# 2        7.5        7.4        7.0      7.9       7.6  $35,014,192
# 3        7.8        7.7        6.9      7.8       7.7  $15,322,921
# 4        8.1        6.6        7.2      7.9       7.8   $6,739,492
#
#      Foreign      Worldwide
# 0  131061209  $187,733,202
# 1   42403567   $60,738,797
# 2    4173591   $39,187,783
# 3   71777528   $87,100,449
# 4   13100000   $19,839,492
#
# [5 rows x 58 columns]

# %%
print(movies.shape)
# Out:
# (117, 58)

# %%
movies['Rating']
# Out:
# 0      8.1
# 1      7.6
# 2      7.7
# 3      7.8
# 4      7.9
#       ...
# 112    8.5
# 113    7.7
# 114    8.0
# 115    7.8
# 116    8.1
# Name: Rating, Length: 117, dtype: float64

# %%
movies['Rating'].mean()
# Out:
# 7.873504273504273

# %%
movies['Runtime'] = pd.to_timedelta(movies['Runtime'])

# %%
movies['Runtime'].mean()
# Out:
# Timedelta('0 days 02:06:33.750000')

# %%
movies['Runtime'].quantile(0.9)
# Out:
# Timedelta('0 days 02:34:30')

# %%
movies['Runtime'].quantile(0.5)
# Out:
# Timedelta('0 days 02:05:30')

# %%
movies['Runtime'].quantile(0.1)
# Out:
# Timedelta('0 days 01:41:00')

# %%
movies[movies['Genre1'] == 'Comedy']['Budget'].mean()
# Out:
# 12200000.0

# %%
movies.groupby('Genre1')['Rating'].mean()
# Out:
# Genre1
# Action       7.872414
# Adventure    7.869231
# Animation    7.900000
# Biography    7.900000
# Comedy       7.807692
# Crime        7.866667
# Drama        7.873913
# Mystery      8.100000
# Name: Rating, dtype: float64

# %%
movies.groupby('Genre1').count()
# Out:
#             X  Title  Rating  TotalVotes  Genre2  Genre3  MetaCritic  Budget  \
# Genre1
# Action     29     29      29          29      29      26          27      29
# Adventure  13     13      13          13      13      11          12      13
# Animation  13     13      13          13      13      13          13      13
# Biography  16     16      16          16      16      11          16      15
# Comedy     13     13      13          13      13       8          11      13
# Crime       9      9       9           9       9       8           9       9
# Drama      23     23      23          23      16       6          21      21
# Mystery     1      1       1           1       1       0           1       1
#
#            Runtime  CVotes10  ...  Votes45A  Votes45AM  Votes45AF  VotesIMDB  \
# Genre1                        ...
# Action          28        29  ...        29         29         29         29
# Adventure       12        13  ...        13         13         13         13
# Animation        5        13  ...        13         13         13         13
# Biography       15        16  ...        16         16         16         16
# Comedy           7        13  ...        13         13         13         13
# Crime            9         9  ...         9          9          9          9
# Drama           19        23  ...        23         23         23         23
# Mystery          1         1  ...         1          1          1          1
#
#            Votes1000  VotesUS  VotesnUS  Domestic  Foreign  Worldwide
# Genre1
# Action            29       29        29        29       29         29
# Adventure         13       13        13        13       13         13
# Animation         13       13        13        13       13         13
# Biography         16       16        16        16       16         16
# Comedy            13       13        13        13       13         13
# Crime              9        9         9         9        9          9
# Drama             23       23        22        23       23         23
# Mystery            1        1         1         1        1          1
#
# [8 rows x 57 columns]

# %%
movies[movies['Genre1'] == 'Mystery']
# Out:
#      X                  Title  Rating  TotalVotes   Genre1    Genre2 Genre3  \
# 72  74  Shutter Island (2010)     8.1      871391  Mystery  Thriller    NaN
#
#     MetaCritic      Budget  Runtime  ...  Votes45A  Votes45AM  Votes45AF  \
# 72        63.0  80000000.0 02:18:00  ...       7.5        7.4        7.6
#
#     VotesIMDB  Votes1000  VotesUS  VotesnUS       Domestic    Foreign  \
# 72        7.3        7.6      7.8       8.1  $128,012,934   166791261
#
#         Worldwide
# 72  $294,804,195
#
# [1 rows x 58 columns]
