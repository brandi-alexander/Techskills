# %%
import pandas as pd
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
shootings = pd.read_csv('NYPD_Shooting_Incident_Data__Historic_.csv')

# %%
shootings.shape
# Out:
# (826, 19)

# %%
shootings.dtypes
# Out:
# INCIDENT_KEY                 int64
# OCCUR_DATE                  object
# OCCUR_TIME                  object
# BORO                        object
# PRECINCT                     int64
# JURISDICTION_CODE            int64
# LOCATION_DESC               object
# STATISTICAL_MURDER_FLAG       bool
# PERP_AGE_GROUP              object
# PERP_SEX                    object
# PERP_RACE                   object
# VIC_AGE_GROUP               object
# VIC_SEX                     object
# VIC_RACE                    object
# X_COORD_CD                  object
# Y_COORD_CD                  object
# Latitude                   float64
# Longitude                  float64
# Lon_Lat                     object
# dtype: object

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
shootings.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME    BORO  PRECINCT  JURISDICTION_CODE  \
# 0     199247701  07/03/2019   00:04:00  QUEENS       114                  2
# 1     199247701  07/03/2019   00:04:00  QUEENS       114                  2
# 2     199247701  07/03/2019   00:04:00  QUEENS       114                  2
# 3     199247701  07/03/2019   00:04:00  QUEENS       114                  2
# 4     199247701  07/03/2019   00:04:00  QUEENS       114                  2
#
#                LOCATION_DESC  STATISTICAL_MURDER_FLAG PERP_AGE_GROUP PERP_SEX  \
# 0  MULTI DWELL - PUBLIC HOUS                    False            <18        M
# 1  MULTI DWELL - PUBLIC HOUS                    False            <18        M
# 2  MULTI DWELL - PUBLIC HOUS                    False            <18        M
# 3  MULTI DWELL - PUBLIC HOUS                    False        UNKNOWN        U
# 4  MULTI DWELL - PUBLIC HOUS                    False          25-44        M
#
# ...

# %%
shootings['OCCUR_DATE']
# Out:
# 0      07/03/2019
# 1      07/03/2019
# 2      07/03/2019
# 3      07/03/2019
# 4      07/03/2019
# 5      07/03/2019
# 6      07/03/2019
# 7      07/03/2019
# 8      07/03/2019
# 9      07/03/2019
# 10     07/03/2019
# 11     07/03/2019
# 12     07/03/2019
# 13     07/03/2019
# 14     07/04/2019
# 15     07/04/2019
# 16     07/04/2019
# 17     07/04/2019
# 18     07/04/2019
# 19     07/04/2019
# 20     07/05/2019
# 21     07/05/2019
# 22     07/05/2019
# 23     07/05/2019
# 24     07/05/2019
# 25     07/05/2019
# 26     07/05/2019
# 27     07/05/2019
# 28     07/05/2019
# 29     07/05/2019
# 30     07/05/2019
# 31     07/05/2019
# 32     07/05/2019
# 33     07/05/2019
# 34     07/05/2019
# 35     07/05/2019
# 36     07/05/2019
# 37     07/05/2019
# 38     07/05/2019
# 39     07/05/2019
# 40     07/05/2019
# 41     07/05/2019
# 42     07/05/2019
# 43     07/05/2019
# 44     07/05/2019
# 45     07/05/2019
# 46     07/05/2019
# 47     07/05/2019
# 48     07/05/2019
# 49     07/05/2019
# ...

# %%
pip install folium
# Out:
# ...
#   Using cached folium-0.11.0-py2.py3-none-any.whl (93 kB)
# ...
#   Using cached branca-0.4.1-py3-none-any.whl (24 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
# folium map we need to provide latitude and longitude folium.Map(location = [40.7484,-73.9857] - nyc)

# %%
m = folium.Map(location = [40.7484,-73.9857])

# %%
# folium.Marker([40.8296, -73.9262]), popup = 'Empire State Building')

# %%
#bins_map = folium.Map(40.7128, -74.0060)
