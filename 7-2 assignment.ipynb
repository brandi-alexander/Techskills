# %% [markdown]
# Write a piece of code that plots the historical populations of Cuba, Dominican Republic, Haiti, and Puerto Rico using the data in the file <u>islandsHistPop.csv</u>.  You may add as many code cells as you need.  Make sure to examine the data file.
#
# 1.  Which island has the largest population?
# 2.  When did the population of the Dominican Republic pass that of Haiti?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv('islandsHistPop.csv')
# Out:
#                    Source: http://www.populstat.info/ Unnamed: 1  \
# 0   Some entries estimated or interpolated using p...        NaN
# 1                                                 NaN        NaN
# 2                                                Year       Cuba
# 3                                                1850     907200
# 4                                                1860    1099400
# 5                                                1870    1321700
# 6                                                1880    1409900
# 7                                                1890    1609100
# 8                                                1900    1600000
# 9                                                1910    2219000
# 10                                               1920    2997000
# 11                                               1930    3647000
# 12                                               1940    4291100
# ...

# %%
islands = pd.read_csv('islandsHistPop.csv', skiprows = 3, index_col = 'Year')

# %%
islands
# Out:
#           Cuba  Dominican Republic    Haiti  Puerto Rico
# Year
# 1850    907200              136500   543000       380000
# 1860   1099400              200000   572000       583300
# 1870   1321700              290000   686000       625000
# 1880   1409900              300000   880000       754300
# 1890   1609100              340000  1085300       839000
# 1900   1600000              600000  1294400       986000
# 1910   2219000              740000  2029700      1118000
# 1920   2997000              879000  1631300      1299800
# 1930   3647000             1256000  2380000      1543900
# 1940   4291100             1674000  2751000      1869300
# 1950   5516000             2353000  3097000      2210700
# 1960   7027000             3231000  3623000      2349500
# 1970   8569100             4423000  4235000      2712000
# 1980   9724000             5697000  5353000      3196500
# 1990  10694500             7170000  6486000      3522000
# ...

# %%
islands.plot()

# %%
islands.plot(kind = 'bar')

# %%
islands.plot.bar(stacked = True)

# %%
islands.plot.bar(stacked = True)

# %%
islands.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbae7b31e90>,
# ...
#       dtype=object)

# %%
islands[islands.index == 1970].head()
# Out:
#          Cuba  Dominican Republic    Haiti  Puerto Rico
# Year
# 1970  8569100             4423000  4235000      2712000

# %%
islands[islands.index == 1970].transpose()
# Out:
# Year                   1970
# Cuba                8569100
# Dominican Republic  4423000
# Haiti               4235000
# Puerto Rico         2712000

# %%
islands[islands.index == 1970].transpose().plot.pie(y=1970)

# %%
islands[islands.index == 2010].transpose().plot.pie(y=2010)

# %%
islands.T.plot.pie(subplots=True, figsize=[200, 200])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbad33be710>,
# ...
#       dtype=object)

# %%
]\\\\\\\\\\\\\\\
# Out:
#   File "<ipython-input-15-484a2a36ffa7>", line 1
#     ]\\\\\\\\\\\\\\\
#     ^
# SyntaxError: invalid syntax
